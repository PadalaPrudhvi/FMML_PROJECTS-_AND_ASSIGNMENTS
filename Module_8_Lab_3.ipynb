# %% [markdown]
# <a href="https://colab.research.google.com/github/PadalaPrudhvi/FMML_PROJECTS-_AND_ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-11 10:51:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   137MB/s    in 0.5s
#
# 2024-04-11 10:52:00 (137 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2980 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 3  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23313   1105.4183v1  Cohomology and cohomology ring of three-dimens...    cs
# 22340  1602.06049v1  Dynamic topic models (DTMs) are very effective...  stat
# 4565    1106.0483v1  Loopy belief propagation performs approximate ...    cs
# 22552  1611.05940v2  We propose a method for finding alternate feat...  stat
# 40540   1306.2118v1  We extend the standard rough set-based approac...    cs
# ...             ...                                                ...   ...
# 31001  1802.00853v1  In this paper, we address the incremental clas...    cs
# 1421   1705.08272v3  Many machine learning tasks require finding pe...    cs
# 23059  1802.10526v1  This is full length article (draft version) wh...  stat
# 21582   1105.0363v2  Inverse inference, or "brain reading", is a re...  stat
# 19847   1303.1468v2  I introduce a temporal belief-network represen...    cs
#
#                                                    title  year  \
# 23313          Cubical Cohomology Ring of 3D Photographs  2011
# 22340                    Scaling up Dynamic Topic Models  2016
# 4565        Learning unbelievable marginal probabilities  2011
# 22552                Finding Alternate Features in Lasso  2016
# 40540  A Novel Approach for Single Gene Selection Usi...  2013
# ...                                                  ...   ...
# 31001  Incremental Classifier Learning with Generativ...  2018
# 1421   Matching neural paths: transfer from recogniti...  2017
# 23059  Application of Rényi and Tsallis Entropies to ...  2018
# 21582  Multi-scale Mining of fMRI data with Hierarchi...  2011
# 19847  Causal Independence for Knowledge Acquisition ...  2013
#
#                                                 keywords
# 23313  [cohomology, cohomology, dimensional, topologi...
# 22340  [effective, discovering, capturing, evolution,...
# 4565   [propagation, approximate, inference, graphica...
# 22552  [alternate, resulting, interpreted, alternate,...
# 40540  [attributes, available, clustering, dimensiona...
# ...                                                  ...
# 31001  [incremental, classifier, catastrophic, forget...
# 1421   [correspondences, correspondences, ambiguous, ...
# 23059  [discussed, identification, collections, numer...
# 21582  [inference, analyzing, functional, resonance, ...
# 19847  [introduce, representation, independence, know...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23313    [cohomology, cohomology, dimensional, topologi...
# 22340    [effective, discovering, capturing, evolution,...
# 4565     [propagation, approximate, inference, graphica...
# 22552    [alternate, resulting, interpreted, alternate,...
# 40540    [attributes, available, clustering, dimensiona...
#                                ...
# 19626    [important, probabilistic, inference, algorith...
# 36336    [algebraic, axiomatizations, algebraic, partic...
# 4173     [autonomous, replicating, synthetic, generativ...
# 731      [challenges, artificial, intelligence, effecti...
# 6692     [deconvnet, understand, theoretically, explana...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8793 words.
# Out of those 4613 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="abb95258-9736-45f8-8871-45d5905feea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abb95258-9736-45f8-8871-45d5905feea8")) {                    Plotly.newPlot(                        "abb95258-9736-45f8-8871-45d5905feea8",                        [{"x":["necessary","connected","efficient","mentioned","foreground","additional","characterize","component","simplicial","triangulation","dimensional","traditionally","computation","incremental","information","algorithm","photographs","invariants","topological","complexes","algorithms","technique","facilitating","reduction","relations","represents","nevertheless","environment","communication","posterior","applications","metropolis","baselines","assignments","magnitude","perplexity","parallelizable","discovering","empirical","usefulness","variational","approximations","knowledge","inference","capturing","evolution","effective","assumptions","distributed","embarrassingly","stochastic","documents","parameters","previously","graphical","propagation","consistent","probabilities","approximate","probability","distributions","approximation","compensate","necessarily","adjusting","averaging","marginals","inaccurate","perturbed","producing","computations","resulting","reasonable","alternate","redundant","interpreted","demonstrate","efficiently","newsgroup","discovery","promising","informative","significant","attributes","classifiers","discriminated","dependence","evaluated","clustering","resultant","correlation","determined","important","available","calculated","expression","classification","dimensionality","selection","experimental","comparing","irrelevant","processes","structure","congressional","inherently","representation","multilingual","vocabulary","associated","challenging","incorporation","retrieval","different","fundamental","transform","nonparametric","inferring","representative","observation","industrial","properties","illustrated","computational","introduce","constructed","contrarily","practical","aggregation","predicting","literature","predictors","predictions","interpolation","observations","considered","theoretical","locations","simulated","aggregating","difficult","heterogeneous","quantities","traditional","performance","influence","optimization","computing","inconsistency","deviation","requirements","unbalanced","significantly","outperforms","feasibility","predicted","ecological","partially","communities","memberships","arbitrary","retrospective","relational","truncations","unbounded","dependent","relationships","regression","prediction","collection","membership","concentration","generalization","complexity","stationary","inequalities","complexities","sequential","rademacher","adversaries","sequences","heterogenous","indicating","parameter","recovering","discovered","heterogeneity","extension","prominent","incorporates","statistical","corrected","incorporating","compactly","blockmodels","additionally","modelling","blockmodel","including","formulation"],"y":[89,70,362,23,21,107,41,109,3,3,179,16,135,31,631,801,10,9,20,6,590,240,10,75,96,42,23,124,53,34,413,6,76,9,46,11,5,25,171,27,48,28,376,206,43,52,267,64,94,1,127,52,264,104,60,63,73,55,107,178,102,115,9,15,11,13,8,7,8,26,35,144,25,10,15,26,545,149,0,57,98,32,257,62,103,2,15,130,153,5,67,30,361,299,29,40,502,67,143,373,76,13,101,327,1,16,384,24,37,107,277,8,116,739,86,68,14,29,29,59,13,210,20,297,351,60,1,148,21,92,124,11,85,20,75,125,155,46,59,10,144,35,15,181,858,58,304,130,9,19,48,6,270,264,18,44,2,66,21,1,80,5,43,2,9,68,71,114,238,84,11,7,109,228,23,2,14,77,4,3,108,0,14,110,21,17,5,66,11,37,161,5,56,1,1,57,52,1,219,88],"type":"bar"},{"x":["necessary","connected","efficient","mentioned","foreground","additional"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4613,), (4613, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Understanding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Trajectory</span> <span style=''>Behavior</span> <span style=''>A</span> <span style=''>Motion</span> <span style=''>Pattern</span> <span style=''>Approach</span> <br/><br/><span style=''>Mining</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>gigantic</span> <span style=''>and</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>is</span> <span style=''>of</span> <span style=''>great</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>to</span> <span style=''>data</span> <span style=''>analysts</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>motion</span> <span style=''>pattern</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>mine</span> <span style=''>frequent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviors</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>trajectory</span> <span style=''>data</span> <span style=''>Motion</span> <span style=''>patterns</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>highly</span> <span style=''>similar</span> <span style=''>flow</span> <span style=''>vector</span> <span style=''>groups</span> <span style=''>in</span> <span style=''>a</span> <span style=''>spatial</span> <span style=''>locality</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.35877862595419846);'>effective</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4473684210526315);'>extracting</span> <span style=''>dominant</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviors</span> <span style=''>in</span> <span style=''>video</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>sequences</span> <span style=''>Inspired</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>motion</span> <span style=''>patterns</span> <span style=''>we</span> <span style=''>have</span> <span style=''>designed</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>solves</span> <span style=''>the</span> <span style=''>general</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>trajectory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>Our</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>four</span> <span style=''>phases</span> <span style=''>flow</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>extraction</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>reachab ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <span style=''>based</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style=''>Polyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>To</span> <span style=''>ensure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>sources</span> <span style=''>in</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>based</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>polyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>which</span> <span style=''>enforces</span> <span style=''>one</span> <span style=''>factor</span> <span style=''>to</span> <span style=''>belong</span> <span style=''>exactly</span> <span style=''>to</span> <span style=''>a</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>A</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>tensors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>polyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>The</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>in</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>models</span> <span style=''>are</span> <span style=''>explored</span> <span style=''>both</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performances</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>unmixing</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperspectral</span> <span style=''>images</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3503836317135551);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>novel</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3503836317135551);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style=''>(CCA)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3136531365313653);'>presented</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.4248366013071894);'>instances</span> <span style=''>of</span> <span style=''>inexact</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3503836317135551);'>stochastic</span> <span style=''>gradient</span> <span style=''>(MSG)</span> <span style=''>and</span> <span style=''>inexact</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentiated</span> <span style=''>gradient</span> <span style=''>(MEG)</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>epsilon</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suboptimality</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>in</span> <span style=''>operatornamepoly(frac1epsilon)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>We</span> <span style=''>also</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>them</span> <span style=''>with</span> <span style=''>other</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>CCA</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3584905660377358);'>theoretically</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>WMRB</span> <span style=''>Learning</span> <span style=''>to</span> <span style=''>Rank</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Scalable</span> <span style=''>Batch</span> <span style=''>Training</span> <span style=''>Approach</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>named</span> <span style=''>Weighted</span> <span style=''>Margin</span> <span style=''>Rank</span> <span style=''>Batch</span> <span style=''>loss</span> <span style=''>(WMRB)</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>Weighted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Rank</span> <span style=''>Pairwise</span> <span style=''>loss</span> <span style=''>(WARP)</span> <span style=''>WMRB</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>new</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>batch</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>item</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilization</span> <span style=''>of</span> <span style=''>parallel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style=''>training</span> <span style=''>In</span> <span style=''>three</span> <span style=''>item</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>tasks</span> <span style=''>WMRB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>WARP</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>baselines</span> <span style=''>Moreover</span> <span style=''>WMRB</span> <span style=''>shows</span> <span style=''>clear</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>as</span> <span style=''>data</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10724533715925394)
# 	experimental (0.13378766140602583)
# 	architecture (0.08357245337159254)
# 	representation (0.13773314203730272)
# 	segmentation (0.06850789096126256)
# 	knowledge (0.13486370157819225)
# 	different (0.26506456241033)
# 	detection (0.11944045911047346)
# 	recognition (0.12876614060258249)
# 	convolutional (0.1366571018651363)
#
# Some Statistics words are:
# 	stochastic (0.1312127236580517)
# 	estimation (0.16302186878727634)
# 	theoretical (0.15009940357852883)
# 	statistical (0.15705765407554673)
# 	algorithm (0.3866799204771372)
# 	variables (0.14612326043737575)
# 	distribution (0.1863817097415507)
# 	dimensional (0.17842942345924453)
# 	inference (0.2047713717693837)
# 	regression (0.17842942345924453)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3369738e-41af-43b2-9057-e21b65f9f2db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3369738e-41af-43b2-9057-e21b65f9f2db")) {                    Plotly.newPlot(                        "3369738e-41af-43b2-9057-e21b65f9f2db",                        [{"x":["necessary","connected","efficient","mentioned","foreground","additional","characterize","component","simplicial","triangulation","dimensional","traditionally","computation","incremental","information","algorithm","photographs","invariants","topological","complexes","algorithms","technique","facilitating","reduction","relations","represents","nevertheless","environment","communication","posterior","applications","metropolis","baselines","assignments","magnitude","perplexity","parallelizable","discovering","empirical","usefulness","variational","approximations","knowledge","inference","capturing","evolution","effective","assumptions","distributed","embarrassingly","stochastic","documents","parameters","previously","graphical","propagation","consistent","probabilities","approximate","probability","distributions","approximation","compensate","necessarily","adjusting","averaging","marginals","inaccurate","perturbed","producing","computations","resulting","reasonable","alternate","redundant","interpreted","demonstrate","efficiently","newsgroup","discovery","promising","informative","significant","attributes","classifiers","discriminated","dependence","evaluated","clustering","resultant","correlation","determined","important","available","calculated","expression","classification","dimensionality","selection","experimental","comparing","irrelevant","processes","structure","congressional","inherently","representation","multilingual","vocabulary","associated","challenging","incorporation","retrieval","different","fundamental","transform","nonparametric","inferring","representative","observation","industrial","properties","illustrated","computational","introduce","constructed","contrarily","practical","aggregation","predicting","literature","predictors","predictions","interpolation","observations","considered","theoretical","locations","simulated","aggregating","difficult","heterogeneous","quantities","traditional","performance","influence","optimization","computing","inconsistency","deviation","requirements","unbalanced","significantly","outperforms","feasibility","predicted","ecological","partially","communities","memberships","arbitrary","retrospective","relational","truncations","unbounded","dependent","relationships","regression","prediction","collection","membership","concentration","generalization","complexity","stationary","inequalities","complexities","sequential","rademacher","adversaries","sequences","heterogenous","indicating","parameter","recovering","discovered","heterogeneity","extension","prominent","incorporates","statistical","corrected","incorporating","compactly","blockmodels","additionally","modelling","blockmodel","including","formulation","synthetic","explained","principled","predictive","appropriate","formulate","statistically","parametric","correction","correcting","automatic","hausdorff","architecture","challenge","preprocessing","distinguish","coefficient","convolutional","registration","segmentation","resolution","similarities","similarity","artificial","obviously","exploiting","analyzing","estimating","experiment","foundation","benchmark","coefficients","comprehensive","considering","especially","guarantees","robustness","recognition","importantly","biologically","classifier","predefined","hierarchical","techniques","therefore","satisfiability","regarding","variables","instances","generally","influential","collected","resources","unprecedented","unc ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	newsgroup
# 	heterogenous
# 	foundational
# 	influencing
# 	occasionally
# 	adversarially
# 	biophysical
# 	regressors
# 	worsening
# 	statisticians
# 	psychiatric
# 	sufficiency
# 	curvatures
# 	nonlinearly
# 	linearization
# 	reparameterization
# 	cytometry
# 	changepoint
# 	changepoints
# 	blockwise
# Some words which never appear in Statistics papers:
# 	simplicial
# 	ecological
# 	truncations
# 	coalition
# 	coalitions
# 	functionalities
# 	communicative
# 	adjectives
# 	elaboration
# 	artefacts
# 	understudied
# 	reciprocal
# 	paragraphs
# 	paraphrase
# 	adjective
# 	demonstrative
# 	disambiguating
# 	colorization
# 	despeckling
# 	productive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077585941587419e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
